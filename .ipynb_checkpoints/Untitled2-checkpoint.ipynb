# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from jupyterthemes import jtplot

#以下のコードを追記する。
# %matplotlib inline
jtplot.style(theme='gruvboxd', context='notebook', ticks=True, grid=False)
df = pd.read_csv("pose_.csv",header=None)
columns_list=[]
for i in range(33):
df.columns = ['Col_1', 'Col_2', 'Col_3']

# %%
df=df[100:]

# %%
df
# Out:
#                 0         1         2         3         4         5    \
# 100    1.648959e+09  0.352715  0.417542  1.614634  0.378775  0.397504
# 101    1.648959e+09  0.352715  0.417542  1.614634  0.378775  0.397504
# 102    1.648959e+09  0.352715  0.417542  1.614634  0.378775  0.397504
# 103    1.648959e+09  0.352715  0.417542  1.614634  0.378775  0.397504
# 104    1.648959e+09  0.352715  0.417542  1.614634  0.378775  0.397504
# ...             ...       ...       ...       ...       ...       ...
# 16627  1.648959e+09  0.153630  0.867742  2.263494  0.233212  0.815180
# 16628  1.648959e+09  0.153630  0.867742  2.263494  0.233212  0.815180
# 16629  1.648959e+09  0.153630  0.867742  2.263494  0.233212  0.815180
# 16630  1.648959e+09  0.153630  0.867742  2.263494  0.233212  0.815180
# 16631  1.648959e+09  0.153630  0.867742  2.263494  0.233212  0.815180
#
#             6         7         8         9    ...       91        92   \
# ...

# %%
# df["0"]=pd.to_datetime(df["0"])
df[0]=pd.to_datetime(df[0],unit="s")
df=df.set_index(0)

# %%
df=df.diff()

# %%
df.plot(subplots=True, layout=(34, 3),figsize=(18, 176), sharex=True)
# Out:
# array([[<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
# ...

# %%
df=df.diff()
df.plot(subplots=True, layout=(34, 3),figsize=(18, 176), sharex=True)
# Out:
# array([[<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
#        [<AxesSubplot:xlabel='0'>, <AxesSubplot:xlabel='0'>,
#         <AxesSubplot:xlabel='0'>],
# ...

# %%
# df = pd.DataFrame(
#     np.random.randint(1, 7, 6000),
#     columns = ['one'])
# df['two'] = df['one'] + np.random.randint(1, 7, 6000)
# ax = df.plot.hist(bins=12, alpha=0.5)
